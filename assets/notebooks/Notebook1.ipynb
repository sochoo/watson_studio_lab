# %%
print("hello world!")
# Out:
# hello world!

# %%
print("User 2 makes the change")
# Out:
# User 2 makes the change

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- -----------------
# absl-py                       0.12.0
# aiohttp                       3.8.1
# aiosignal                     1.2.0
# appdirs                       1.4.4
# argon2-cffi                   20.1.0
# astropy                       5.0
# astunparse                    1.6.3
# async-generator               1.10
# async-timeout                 4.0.1
# attrs                         21.2.0
# autoai-libs                   1.13.2
# autovizwidget                 0.18.0
# av                            8.0.3
# azure-core                    1.21.0
# azure-cosmos                  4.2.0
# backcall                      0.2.0
# beautifulsoup4                4.10.0
# biopython                     1.78
# black                         19.10b0
# bleach                        4.0.0
# blinker                       1.4
# bokeh                         2.3.3
# boto3                         1.18.21
# ...
